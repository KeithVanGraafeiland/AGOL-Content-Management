# %%
import arcgis
from arcgis.gis import GIS
from arcgis.mapping import WebMap
# from credentials.py import AGO_username, AGO_password
from arcgis.features import FeatureLayer
from ipywidgets import *
import random
import time

gis = GIS("https://esri.maps.arcgis.com/", "esri_oceans", "ocean15ocean")
arcgis.env.Overwrite = True

# %%
services_list = ['https://oceans6.arcgis.com/arcgis/rest/services/AIS/2021_US_Vessel_Traffic/FeatureServer/2','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/1','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/2','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/3','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/4','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/5','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/6',
                 'https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/7','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/8','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/9','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/10','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/11','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2020_US_Vessel_Traffic/FeatureServer/12','https://oceans6.arcgis.com/arcgis/rest/services/AIS/2021_US_Vessel_Traffic/FeatureServer/0']

ports_list = ['Baltimore, MD', 'Norfolk, VA', 'Charleston, SC', 'Long Beach, CA', 'Portland, OR', 'Treasure Island, CA', 'San Diego, CA', 'Port of Miami, FL', 'Westhaven, OR',
             'Honolulu, HI', 'Boston, MA', 'California, MD', 'Tampa, FL', 'Shelter Cove Golf Course', 'California Coastal National Monument', 'Port Orford Heads State Park', 
             'Yoakam Point State Natural Site', "Eben H Carruthers Memorial Park"]

coords_list = [[47.600039, -122.356364],[34.404451, -119.685383],[34.144069, -119.212957],[33.714139, -118.221141],[33.585852, -117.881165],
               [33.451575, -117.696887],[33.203045, -117.404376],[32.756493, -117.263471],[32.717578, -117.186996],[32.673373, -117.141506], 
               [27.638864, -97.237970],[27.800170, -97.377617],[28.681438, -95.975401],[29.310312, -94.834367], [26.713486, -82.258304], 
               [47.727391, -122.540958],[47.679334, -122.421911], [61.225274, -149.922595], [59.609784, -151.406522], [60.544327, -145.774484],
               [55.340620, -131.663404], [41.477143, -71.350951], [41.632000, -71.215210], [41.295224, -70.096536], [41.286292, -70.209317],
               [42.041744, -70.175929], [35.776640, -75.532966], [35.191035, -75.760074], [34.702781, -76.676660], [34.216704, -77.813745],
               [33.880896, -78.012099],[32.763897, -79.908614],[32.090869, -81.084666], [31.047419, -81.423183], [30.709450, -81.450648],
               [30.400497, -81.410566],[30.321883, -81.655955],[29.898257, -81.307740], [28.410533, -80.593660], [27.471794, -80.290463]]

vesselGroup_list = ['Cargo', 'Fishing', 'Military', 'Not_Available', 'Passenger', 'Pleasure', 'Unknown', 'Tanker', 'Tow']

lay_def = str("\"" +"vessel_group = " + "'" + random.choice(vesselGroup_list)+ "'" + "\"")

# %%
# Create a map widget
# location = arcgis.geocoding.geocode(random.choice(ports_list), max_locations=1)[0]
# ais_map = gis.map((random.choice(ports_list)))
ais_map = gis.map()
# len(coords_list[1])
# ais_map.extent = location['extent']
ais_map.basemap = 'hybrid'
ais_map.zoom = 14
service = services_list[0]
service = 'https://oceans6.arcgis.com/arcgis/rest/services/AIS/2017_US_Vessel_Traffic/FeatureServer/11'
# print(service)
# print(str(service.split('/')[7]) + "_" + str(service.split('/')[9]))
ais_layer = FeatureLayer(service)
# ais_layer.layerDefinition.definitionExpression = lay_def
# ais_map.center = (service)
ais_map.add_layer(ais_layer)
ais_map.layout=Layout(height='400px', width='600px')

ais_map
# Out:
# MapView(layout=Layout(height='400px', width='600px'))
# <div class="map-static-img-preview-5079edb2-1758-438b-9fee-5577576ff6cd"><img src="data:image/png;base64,..."></img></div>
# <div class="map-html-embed-preview-5079edb2-1758-438b-9fee-5577576ff6cd"></div>

# %%
ais_map.center = random.choice(coords_list)
ais_map.zoom = 14
ais_map.update
# Out:
# <bound method MapView.update of MapView(jupyter_target='notebook', layout=Layout(height='400px', width='600px'), ready=True)>

# %%
ais_map.take_screenshot(file_path=r"E:\Temp\thumbnails\\" + str(service.split('/')[7]) + "_" + str(service.split('/')[9]))
# Out:
# <img src=data:image/png;base64,...></img>
